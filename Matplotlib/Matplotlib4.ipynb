# %% [markdown]
# # BarCharts

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company = ['GOOGLE','AMZN','MSFT','FB']
revenue = [90,136,89, 27]
profit=[40,2,34,12]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos,company)  #Get or set the current tick locations and labels of the x-axis.
# Out:
# ([<matplotlib.axis.XTick at 0x1ced70eb010>,
#   <matplotlib.axis.XTick at 0x1ced70eaf80>,
#   <matplotlib.axis.XTick at 0x1ced70eabf0>,
#   <matplotlib.axis.XTick at 0x1ced7107340>],
#  [Text(0, 0, 'GOOGLE'),
#   Text(1, 0, 'AMZN'),
#   Text(2, 0, 'MSFT'),
#   Text(3, 0, 'FB')])

# %%
plt.xticks(xpos,company)
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stocks")
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stocks")
plt.bar(xpos,revenue,label ="Revenue")
plt.bar(xpos,profit,label="Profit")
plt.legend()

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stocks")
plt.bar(xpos-0.2,revenue,label ="Revenue")
plt.bar(xpos+0.2,profit,label="Profit")
plt.legend()

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stocks")
plt.bar(xpos-0.2,revenue,width=0.4,label ="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.legend()

# %%
plt.yticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stocks")
plt.barh(xpos-0.2,revenue,label ="Revenue")  #width doesn't work here as it is
plt.barh(xpos+0.2,profit,label="Profit")
plt.legend()
