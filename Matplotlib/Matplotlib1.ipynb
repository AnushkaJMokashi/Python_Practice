# %% [markdown]
# # Matplotlib

# %% [markdown]
# * Used for data visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #pyplot is main plot object of matplotlib
#
# https://matplotlib.org/stable/api/pyplot_summary.html

# %%
#to render the charts inline use 
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7,]
y = [50,51,52,48,47,49,46]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linestyle='dashdot',linewidth=5)
